# %% [markdown]
# # Introduction

# %% [markdown]
# <center><img src="https://i.imgur.com/9hLRsjZ.jpg" height=400></center>
#
# This dataset was scraped from [nextspaceflight.com](https://nextspaceflight.com/launches/past/?page=1) and includes all the space missions since the beginning of Space Race between the USA and the Soviet Union in 1957!

# %% [markdown]
# ### Install Package with Country Codes

# %%
# %pip install iso3166
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ### Upgrade Plotly
#
# Run the cell below if you are working with Google Colab.

# %%
# %pip install --upgrade plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 15.2 MB 7.2 MB/s
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.5.0
#     Uninstalling plotly-5.5.0:
#       Successfully uninstalled plotly-5.5.0
# ...

# %% [markdown]
# ### Import Statements

# %%
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# These might be helpful:
from iso3166 import countries
from datetime import datetime, timedelta

# %% [markdown]
# ### Notebook Presentation

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ### Load the Data

# %%
df_data = pd.read_csv('mission_launches.csv')
df_data
# Out:
#       Unnamed: 0  Unnamed: 0.1 Organisation  \
# 0              0             0       SpaceX
# 1              1             1         CASC
# 2              2             2       SpaceX
# 3              3             3    Roscosmos
# 4              4             4          ULA
# ...          ...           ...          ...
# 4319        4319          4319      US Navy
# 4320        4320          4320         AMBA
# 4321        4321          4321      US Navy
# 4322        4322          4322    RVSN USSR
# 4323        4323          4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# ...

# %% [markdown]
# # Preliminary Data Exploration
#
# * What is the shape of `df_data`?
# * How many rows and columns does it have?
# * What are the column names?
# * Are there any NaN values or duplicates?

# %%
df_data.shape
# Out:
# (4324, 9)

# %%
df_data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Organisation', 'Location', 'Date',
#        'Detail', 'Rocket_Status', 'Price', 'Mission_Status'],
#       dtype='object')

# %%
df_data.isnull().values.any()
# Out:
# True

# %%
df_data.isnull()
# Out:
#       Unnamed: 0  Unnamed: 0.1  Organisation  Location   Date  Detail  \
# 0          False         False         False     False  False   False
# 1          False         False         False     False  False   False
# 2          False         False         False     False  False   False
# 3          False         False         False     False  False   False
# 4          False         False         False     False  False   False
# ...          ...           ...           ...       ...    ...     ...
# 4319       False         False         False     False  False   False
# 4320       False         False         False     False  False   False
# 4321       False         False         False     False  False   False
# 4322       False         False         False     False  False   False
# 4323       False         False         False     False  False   False
#
#       Rocket_Status  Price  Mission_Status
# 0             False  False           False
# ...

# %%
df_data
# Out:
#       Unnamed: 0  Unnamed: 0.1 Organisation  \
# 0              0             0       SpaceX
# 1              1             1         CASC
# 2              2             2       SpaceX
# 3              3             3    Roscosmos
# 4              4             4          ULA
# ...          ...           ...          ...
# 4319        4319          4319      US Navy
# 4320        4320          4320         AMBA
# 4321        4321          4321      US Navy
# 4322        4322          4322    RVSN USSR
# 4323        4323          4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# ...

# %% [markdown]
# ## Data Cleaning - Check for Missing Values and Duplicates
#
# Consider removing columns containing junk data.

# %%
df_data['Mission_Status'].isnull().values.any()
# Out:
# False

# %%
df_data['Price'].fillna(df_data.mean(), inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
df_data['Price'].isnull().values.any()
# Out:
# False

# %% [markdown]
# ## Descriptive Statistics

# %%
df_data.describe()
# Out:
#        Unnamed: 0  Unnamed: 0.1
# count    4,324.00      4,324.00
# mean     2,161.50      2,161.50
# std      1,248.38      1,248.38
# min          0.00          0.00
# 25%      1,080.75      1,080.75
# 50%      2,161.50      2,161.50
# 75%      3,242.25      3,242.25
# max      4,323.00      4,323.00

# %%
df_data.describe
# Out:
# <bound method NDFrame.describe of       Unnamed: 0  Unnamed: 0.1 Organisation  \
# 0              0             0       SpaceX
# 1              1             1         CASC
# 2              2             2       SpaceX
# 3              3             3    Roscosmos
# 4              4             4          ULA
# ...          ...           ...          ...
# 4319        4319          4319      US Navy
# 4320        4320          4320         AMBA
# 4321        4321          4321      US Navy
# 4322        4322          4322    RVSN USSR
# 4323        4323          4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# ...

# %%
df_data
# Out:
#       Unnamed: 0  Unnamed: 0.1 Organisation  \
# 0              0             0       SpaceX
# 1              1             1         CASC
# 2              2             2       SpaceX
# 3              3             3    Roscosmos
# 4              4             4          ULA
# ...          ...           ...          ...
# 4319        4319          4319      US Navy
# 4320        4320          4320         AMBA
# 4321        4321          4321      US Navy
# 4322        4322          4322    RVSN USSR
# 4323        4323          4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# ...

# %% [markdown]
# # Number of Launches per Company
#
# Create a chart that shows the number of space mission launches by organisation.

# %%
rocket_launch = df_data['Organisation'].value_counts()
org = df_data['Organisation']
fig = plt.figure(figsize =(10, 7))
plt.xlabel("Organisation")
plt.ylabel("No. of launches")
plt.bar(org[0:10], rocket_launch[0:10])
plt.show()

# %%
plt.figure(figsize=(22,6))
ax = sns.countplot(x=df_data['Organisation'])
ax.axes.set_title("launch by company",fontsize=14)

plt.xticks(rotation=45, ha='right')
ax.set_ylabel("Number of Launches",fontsize=16)
ax.tick_params(labelsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Number of Active versus Retired Rockets
#
# How many rockets are active compared to those that are decomissioned?

# %%
rocket_active = df_data['Rocket_Status'].value_counts('StatusActive')
rocket_active
# Out:
# StatusRetired   0.82
# StatusActive    0.18
# Name: Rocket_Status, dtype: float64

# %%
rocket_retired = df_data['Rocket_Status'].value_counts('StatusRetired')
rocket_retired
# Out:
# StatusRetired   0.82
# StatusActive    0.18
# Name: Rocket_Status, dtype: float64

# %% [markdown]
# # Distribution of Mission Status
#
# How many missions were successful?
# How many missions failed?

# %%
rocket_sec_fail = df_data['Mission_Status'].value_counts('Success')
rocket_sec_fail*100
# Out:
# Success             89.71
# Failure              7.84
# Partial Failure      2.36
# Prelaunch Failure    0.09
# Name: Mission_Status, dtype: float64

# %% [markdown]
# # How Expensive are the Launches?
#
# Create a histogram and visualise the distribution. The price column is given in USD millions (careful of missing values).

# %%
a = np.array([df_data['Price']])
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(a)
# Show plot
plt.show()

# %% [markdown]
# # Use a Choropleth Map to Show the Number of Launches by Country
#
# * Create a choropleth map using [the plotly documentation](https://plotly.com/python/choropleth-maps/)
# * Experiment with [plotly's available colours](https://plotly.com/python/builtin-colorscales/). I quite like the sequential colour `matter` on this map.
# * You'll need to extract a `country` feature as well as change the country names that no longer exist.
#
# Wrangle the Country Names
#
# You'll need to use a 3 letter country code for each country. You might have to change some country names.
#
# * Russia is the Russian Federation
# * New Mexico should be USA
# * Yellow Sea refers to China
# * Shahrud Missile Test Site should be Iran
# * Pacific Missile Range Facility should be USA
# * Barents Sea should be Russian Federation
# * Gran Canaria should be USA
#
#
# You can use the iso3166 package to convert the country names to Alpha3 format.

# %%
df_data["Country"] = df_data["Location"].apply(lambda location: location.split(", ")[-1])
for i in df_data["Country"]:
  def iso(country):
    try:
      return countries.get(country).alpha3
    except:
      return ("RUS")
df_data['ISO'] = df_data.Country.apply(lambda country: iso(country))

# %%
df_data
# Out:
#       Unnamed: 0  Unnamed: 0.1 Organisation  \
# 0              0             0       SpaceX
# 1              1             1         CASC
# 2              2             2       SpaceX
# 3              3             3    Roscosmos
# 4              4             4          ULA
# ...          ...           ...          ...
# 4319        4319          4319      US Navy
# 4320        4320          4320         AMBA
# 4321        4321          4321      US Navy
# 4322        4322          4322    RVSN USSR
# 4323        4323          4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# ...

# %%
if df_data['ISO'].str.contains('USA').any():
    print ("loc is there")
# Out:
# Mel is there

# %%
iso = df_data.ISO.value_counts()
px.choropleth(df_data, locations=iso.index, color=iso.values, hover_name=iso.index, title='Number of Lauches', color_continuous_scale="matter")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Use a Choropleth Map to Show the Number of Failures by Country

# %%
fail = df_data.Mission_Status.value_counts()
fail.Failure
# Out:
# 339

# %%
print(iso.index)
print(fail.index)
print(fail.values)
print(iso.values)
# Out:
# Index(['RUS', 'USA', 'KAZ', 'FRA', 'CHN', 'JPN', 'IND', 'NZL', 'ISR', 'KEN',
#        'AUS', 'BRA'],
#       dtype='object')
# Index(['Success', 'Failure', 'Partial Failure', 'Prelaunch Failure'], dtype='object')
# [3879  339  102    4]
# [1464 1344  701  303  268  126   76   13   11    9    6    3]

# %%
px.choropleth(df_data['Mission_Status'], locations=iso.index, color=iso.values, hover_name=iso.index, title='Number of Lauches', color_continuous_scale="matter")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_data
# Out:
#       Unnamed: 0  Unnamed: 0.1 Organisation  \
# 0              0             0       SpaceX
# 1              1             1         CASC
# 2              2             2       SpaceX
# 3              3             3    Roscosmos
# 4              4             4          ULA
# ...          ...           ...          ...
# 4319        4319          4319      US Navy
# 4320        4320          4320         AMBA
# 4321        4321          4321      US Navy
# 4322        4322          4322    RVSN USSR
# 4323        4323          4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# ...

# %% [markdown]
# # Create a Plotly Sunburst Chart of the countries, organisations, and mission status.

# %%
country = list(df_data["Country"])
organization = list(df_data['Organisation'])
mission = list(df_data['Mission_Status'])
sun = (country,organization,mission)
fig = px.sunburst(df_data, path = ["Country", "Organisation", "Mission_Status"], title = "Sunburst Chart")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Analyse the Total Amount of Money Spent by Organisation on Space Missions

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-284-1dd1cd7e881b> in <module>()
#       3   time = ((i.split(",")[1]))
#       4   year = time[0:5]
# ----> 5   year_laun.push(year)
#
# AttributeError: 'list' object has no attribute 'push'

# %%
x = df_data['Organisation'].head(10)
y = df_data['Price'].head(10)
fig = plt.figure(figsize =(10, 7))
# Horizontal Bar Plot
plt.bar(x[0:10], y[0:10])
# Show Plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-263-10416730a398> in <module>()
#       3 fig = plt.figure(figsize =(10, 7))
#       4 # Horizontal Bar Plot
# ----> 5 plt.bar(x[0:10], y[0:10])
#       6
#       7 # Show Plot
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2407     return gca().bar(
#    2408         x, height, width=width, bottom=bottom, align=align,
# -> 2409         **({"data": data} if data is not None else {}), **kwargs)
#    2410
#    2411
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
# ...

# %% [markdown]
# # Analyse the Amount of Money Spent by Organisation per Launch

# %% [markdown]
# # Chart the Number of Launches per Year

# %%
year_laun = []
for i in df_data['Date']:
  time = ((i.split(",")[1]))
  year = time[0:5]
  year_laun.append(year)
df_data['year'] = year_laun
df_data
# Out:
#       Unnamed: 0  Unnamed: 0.1 Organisation  \
# 0              0             0       SpaceX
# 1              1             1         CASC
# 2              2             2       SpaceX
# 3              3             3    Roscosmos
# 4              4             4          ULA
# ...          ...           ...          ...
# 4319        4319          4319      US Navy
# 4320        4320          4320         AMBA
# 4321        4321          4321      US Navy
# 4322        4322          4322    RVSN USSR
# 4323        4323          4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# ...

# %%
month_laun = []
for i in df_data['Date']:
  time = ((i.split(",")[0]))
  month = time[3:7]
  month_laun.append(month)
df_data['month'] = month_laun
df_data
# Out:
#       Unnamed: 0  Unnamed: 0.1 Organisation  \
# 0              0             0       SpaceX
# 1              1             1         CASC
# 2              2             2       SpaceX
# 3              3             3    Roscosmos
# 4              4             4          ULA
# ...          ...           ...          ...
# 4319        4319          4319      US Navy
# 4320        4320          4320         AMBA
# 4321        4321          4321      US Navy
# 4322        4322          4322    RVSN USSR
# 4323        4323          4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# ...

# %%
test = pd.DataFrame(df_data.groupby(["Country", "year"])["Location"].count())
test = test.reset_index(level=[0,1])
fig = px.bar(test, x='year', y='Location', color ='Country')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Chart the Number of Launches Month-on-Month until the Present
#
# Which month has seen the highest number of launches in all time? Superimpose a rolling average on the month on month time series chart.

# %%
plt.figure(figsize=(8,6))
ax = sns.countplot(x='month',data= df_data)
ax.axes.set_title("Month vs. Number of Launches",fontsize=14)
ax.set_xlabel("Month",fontsize=16)
ax.set_ylabel("Number of Launches",fontsize=16)
ax.tick_params(labelsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Launches per Month: Which months are most popular and least popular for launches?
#
# Some months have better weather than others. Which time of year seems to be best for space missions?

# %% [markdown]
# # How has the Launch Price varied Over Time?
#
# Create a line chart that shows the average price of rocket launches over time.

# %% [markdown]
# # Chart the Number of Launches over Time by the Top 10 Organisations.
#
# How has the dominance of launches changed over time between the different players?

# %% [markdown]
# # Cold War Space Race: USA vs USSR
#
# The cold war lasted from the start of the dataset up until 1991.

# %% [markdown]
# ## Create a Plotly Pie Chart comparing the total number of launches of the USSR and the USA
#
# Hint: Remember to include former Soviet Republics like Kazakhstan when analysing the total number of launches.

# %% [markdown]
# ## Create a Chart that Shows the Total Number of Launches Year-On-Year by the Two Superpowers

# %% [markdown]
# ## Chart the Total Number of Mission Failures Year on Year.

# %% [markdown]
# ## Chart the Percentage of Failures over Time
#
# Did failures go up or down over time? Did the countries get better at minimising risk and improving their chances of success over time?

# %% [markdown]
# # For Every Year Show which Country was in the Lead in terms of Total Number of Launches up to and including including 2020)
#
# Do the results change if we only look at the number of successful launches?

# %% [markdown]
# # Create a Year-on-Year Chart Showing the Organisation Doing the Most Number of Launches
#
# Which organisation was dominant in the 1970s and 1980s? Which organisation was dominant in 2018, 2019 and 2020?
